# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score
from sklearn.inspection import DecisionBoundaryDisplay

# !wget https://archive.ics.uci.edu/static/public/53/iris.zip
# !unzip iris.zip
df = pd.read_csv("iris.data", names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
)
# Dos clases (clasificación binaria)
df = df[df['class'].isin(['Iris-setosa', 'Iris-versicolor'])]
# x, y
x = df[['sepal_length', 'sepal_width']]
y = df['class']
# Creación de un clasificador lineal (perceptron)
clf = Perceptron()
# Entrenamiento del clasificador
clf.fit(x, y)
# Predicción para datos de entrenamiento
y_pred = clf.predict(x)
# Tasa de aciertos
acc_score = accuracy_score(y, y_pred)
print('Tasa de aciertos: {acc_sc}'.format(acc_sc=acc_score))
# Mostrar fronteras de decisión del clasificador
DecisionBoundaryDisplay.from_estimator(clf, x, response_method="predict")
# Mostrar datos de entrenamiento
colores = {'Iris-setosa':'orange', 'Iris-versicolor':'green' }
plt.scatter(x['sepal_length'], x['sepal_width'], c=y.map(colores), edgecolor='k')
plt.xlabel("sepal_length")
plt.ylabel("sepal_width")
# Out:
# --2026-08-17 11:39:23--  https://archive.ics.uci.edu/static/public/53/iris.zip
# S'està resolent archive.ics.uci.edu (archive.ics.uci.edu)… error: Fallada temporal a la resolució de noms.
# wget: no s'ha pogut resoldre l'adreça del servidor «‘archive.ics.uci.edu’»
# unzip:  cannot find or open iris.zip, iris.zip.zip or iris.zip.ZIP.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 9
#       5 from sklearn.inspection import DecisionBoundaryDisplay
#       6
#       7 get_ipython().system('wget https://archive.ics.uci.edu/static/public/53/iris.zip')
#       8 get_ipython().system('unzip iris.zip')
# ----> 9 df = pd.read_csv("iris.data", names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
#      10 )
#      11 # Dos clases (clasificación binaria)
#      12 df = df[df['class'].isin(['Iris-setosa', 'Iris-versicolor'])]
#
# ...

# %% [markdown]
# Exercici 1:
#
# Aquest exemple fa un clasificador lineal binari amb perceptrón. Com que hi ha 3 classes s'ha tingut que eliminar una. Fes un classificador amb una altra combinació de classes.

# %% [markdown]
# Exercici 2:
#
# No elimines cap atribut, ara no es pot representar gràficament, però es pot calcular l'accuracy.

# %% [markdown]
# Exercici 3:
#
# Elimina atributs fins quedar-te en 3. Ara es pot representar en un gràfic 3D amb els punts de cada classe en un color distint. Entrena un classificador i mostra les prediccions al gràfic. Els punts incorrectament classificats es veuran en negre.

# %% [markdown]
# Exercici 4:
#
# Imprimeix els paràmetres del model perceptron entrenat de l'anterior exercici. Interpreta el significat dels paràmetres amb les teues paraules i de forma gràfica.
